# %%
pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -------------------------- ------------- 6.6/9.9 MB 33.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 32.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.express as px

matches = [1, 2, 3, 4, 5, 6]
runs = [45, 78, 102, 56, 89, 120]

fig = px.line(x=matches, y=runs, markers=True,
              title="Cricket Player Runs per Match",
              labels={"x": "Match Number", "y": "Runs Scored"})

fig.show()

# %%
import plotly.express as px

teams = ["India", "Australia", "England", "Pakistan", "South Africa"]
total_runs = [320, 280, 305, 290, 275]

fig = px.bar(x=teams, y=total_runs,
             title="Team Total Runs Comparison",
             labels={"x": "Team", "y": "Total Runs"},
             color=total_runs)

fig.show()

# %%
import plotly.express as px

runs = [45, 78, 102, 56, 89, 120]
strike_rate = [110, 125, 140, 115, 130, 150]

fig = px.scatter(x=runs, y=strike_rate,
                 title="Runs vs Strike Rate",
                 labels={"x": "Runs", "y": "Strike Rate"},
                 trendline="ols")

fig.show()

# %%
pip show statsmodels
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: statsmodels

# %%
pip install statsmodels
# Out:
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ------------------------- -------------- 6.0/9.5 MB 30.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 25.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ------ --------------------------------- 5.5/36.6 MB 25.4 MB/s eta 0:00:02
#    ------------ --------------------------- 11.3/36.6 MB 26.4 MB/s eta 0:00:01
#    ------------------ --------------------- 17.3/36.6 MB 27.4 MB/s eta 0:00:01
#    ------------------------- -------------- 23.6/36.6 MB 27.5 MB/s eta 0:00:01
#    --------------------------------- ------ 30.4/36.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.6 MB 29.1 MB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 27.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# ...

# %%
import plotly.express as px

fig = px.line(x=[1,2,3], y=[10,20,30])
fig.show()

# %%
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "browser"

# %%
pip install ipywidgets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
